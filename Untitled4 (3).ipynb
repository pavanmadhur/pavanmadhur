# %%
import pandas as pd

# %%
df=pd.read_csv(r"https://raw.githubusercontent.com/singhrau0/Big-Data-Preprocessing/main/youtubesample.csv")

# %%
df
# Out:
#          video_id trending_date  \
# 0     m8Dqg8iz5Fo      18.09.05
# 1     2yCp-Dj5-7c      17.16.12
# 2     H00djJq68VE      17.27.12
# 3     oTObwUiXdYY      17.19.11
# 4     yvicqMrAHvQ      18.05.02
# ...           ...           ...
# 4995  bqFjyo7I8fY      18.01.03
# 4996  K0u_kAWLJOA      18.25.01
# 4997  XGd1dq1BatM      18.19.03
# 4998  vGTTSdrV37U      18.04.04
# 4999  DkeiKbqa02g      18.22.05
#
#                                                   title  \
# 0     MY INSTAGRAM FOLLOWERS PICK MY FULL FACE OF MA...
# 1     Does Tiffany Haddish Think NeNe Leakes Is Funn...
# 2     Panettone (Italian Christmas Bread) - Food Wishes
# 3     7.3 Magnitude Earthquake Along Iraq-Iran Borde...
# 4               Turkish Airlines - 5 Senses with Dr. Oz
# ...                                                 ...
# 4995          Red Velvet 레드벨벳 '봐 (Look)' Dance Practice
# 4996                   God of War – Story Trailer | PS4
# 4997  Halsey - Alone (Audio) ft. Big Sean, Stefflon Don
# ...

# %%
df.isnull().sum()
# Out:
# video_id                   0
# trending_date              0
# title                      0
# channel_title              0
# category_id                0
# publish_time               0
# tags                       0
# views                      0
# likes                      0
# dislikes                   0
# comment_count              0
# thumbnail_link             0
# comments_disabled          0
# ratings_disabled           0
# video_error_or_removed     0
# description               55
# Genre                      0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   video_id                5000 non-null   object
#  1   trending_date           5000 non-null   object
#  2   title                   5000 non-null   object
#  3   channel_title           5000 non-null   object
#  4   category_id             5000 non-null   int64
#  5   publish_time            5000 non-null   object
#  6   views                   5000 non-null   int64
#  7   likes                   5000 non-null   int64
#  8   dislikes                5000 non-null   int64
#  9   comment_count           5000 non-null   int64
#  10  comments_disabled       5000 non-null   bool
#  11  ratings_disabled        5000 non-null   bool
#  12  video_error_or_removed  5000 non-null   bool
#  13  Genre                   5000 non-null   object
# ...

# %%
df.nunique()
# Out:
# video_id                  3228
# trending_date              205
# title                     3239
# channel_title             1409
# category_id                 16
# publish_time              3206
# views                     4991
# likes                     4730
# dislikes                  2559
# comment_count             3534
# comments_disabled            2
# ratings_disabled             2
# video_error_or_removed       2
# Genre                       16
# dtype: int64

# %%
df.drop(['description','tags','thumbnail_link'],axis=1,inplace=True)

# %%
df.describe()
# Out:
#        category_id         views         likes       dislikes  comment_count
# count   5000.00000  5.000000e+03  5.000000e+03    5000.000000   5.000000e+03
# mean      19.94620  2.407597e+06  8.074875e+04    3459.565800   9.169436e+03
# std        7.52605  7.221182e+06  2.609361e+05   15092.820014   4.136390e+04
# min        1.00000  7.130000e+02  0.000000e+00       0.000000   0.000000e+00
# 25%       17.00000  2.470338e+05  5.527000e+03     201.000000   6.100000e+02
# 50%       24.00000  6.854875e+05  1.795550e+04     637.000000   1.844500e+03
# 75%       25.00000  1.885173e+06  5.651375e+04    2046.000000   5.727250e+03
# max       43.00000  1.844465e+08  5.530568e+06  487820.000000   1.213172e+06

# %%
import datetime as dt

# %%
df['publish_time']=pd.to_datetime(df['publish_time'],utc=True)

# %%
df['trending_date']=pd.to_datetime(df['trending_date'],format="%y.%d.%m")

# %%
df['Pyear']=df['publish_time'].dt.year

# %%
df['Pmonth']=df['publish_time'].dt.month

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   video_id                5000 non-null   object
#  1   trending_date           5000 non-null   datetime64[ns]
#  2   title                   5000 non-null   object
#  3   channel_title           5000 non-null   object
#  4   category_id             5000 non-null   int64
#  5   publish_time            5000 non-null   datetime64[ns, UTC]
#  6   tags                    5000 non-null   object
#  7   views                   5000 non-null   int64
#  8   likes                   5000 non-null   int64
#  9   dislikes                5000 non-null   int64
#  10  comment_count           5000 non-null   int64
#  11  thumbnail_link          5000 non-null   object
#  12  comments_disabled       5000 non-null   bool
#  13  ratings_disabled        5000 non-null   bool
# ...

# %%
df[df["Genre"]=="Music"]
# Out:
#          video_id trending_date  \
# 5     qDAxDcjgn-8    2017-11-18
# 6     kton-qrKNLc    2018-03-08
# 7     oRArmtMA9AI    2018-03-15
# 10    RQm0nKoODo4    2018-03-13
# 22    TyHvyGVs42U    2017-11-23
# ...           ...           ...
# 4982  HTi1c_tLnqw    2017-12-17
# 4990  Bju5Enu--80    2017-12-07
# 4995  bqFjyo7I8fY    2018-03-01
# 4997  XGd1dq1BatM    2018-03-19
# 4999  DkeiKbqa02g    2018-05-22
#
#                                                   title      channel_title  \
# 5                Taylor Swift - Reputation ALBUM REVIEW      theneedledrop
# 6                           Meghan Trainor - No Excuses  MeghanTrainorVEVO
# 7               Marshmello - FLY (Official Music Video)         Marshmello
# 10             Take On Me in 20 Styles ft. Seth Everman   Ten Second Songs
# 22            Luis Fonsi, Demi Lovato - Échame La Culpa      LuisFonsiVEVO
# ...                                                 ...                ...
# ...

# %%
df['video_id'].nunique()
# Out:
# 3228

# %%
x=df[['views','dislikes','comment_count','category_id']]

# %%
x.corr()
# Out:
#                   views  dislikes  comment_count  category_id
# views          1.000000  0.641098       0.645085    -0.170819
# dislikes       0.641098  1.000000       0.631353    -0.077782
# comment_count  0.645085  0.631353       1.000000    -0.099711
# category_id   -0.170819 -0.077782      -0.099711     1.000000

# %%
y=df['likes']

# %%
y
# Out:
# 0        35939
# 1         1191
# 2         8274
# 3          149
# 4          606
#          ...
# 4995    159805
# 4996     83372
# 4997     66964
# 4998     13113
# 4999    781317
# Name: likes, Length: 5000, dtype: int64

# %%
#splittind the data into two part training and testing data
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=2529)

# %%
x_train
# Out:
#         views  dislikes  comment_count  category_id
# 4758   339352       228           2283           28
# 3387  8898755     31642              0           28
# 2146   331267       262           2910           24
# 622    134863        29            287           24
# 4274  1062120       620            961           24
# ...       ...       ...            ...          ...
# 4590   578506      3616           2622           24
# 4476   738740      1575           1530           23
# 3656   342075       128            375           10
# 4836   298714       214            534           27
# 2876  5505292      5189           3266           26
#
# [4000 rows x 4 columns]

# %%
x_test
# Out:
#         views  dislikes  comment_count  category_id
# 364    277410       133           1458           23
# 3448   170622        88            590           28
# 564    289826       788           2365           25
# 3664   519649      1529           1098           17
# 4844  3509600      2285           9951           22
# ...       ...       ...            ...          ...
# 1310   430640       315          15456           24
# 2364  3969182     18662          66232           10
# 251    560384       187           7509           23
# 4504   491800       297           9368           23
# 509    105670       184            396           28
#
# [1000 rows x 4 columns]

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.predict([[40000,50,200,1]])
# Out:
# C:\Users\admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([39553.7618589])
